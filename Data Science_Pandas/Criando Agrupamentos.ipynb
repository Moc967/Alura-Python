# %% [markdown]
# # Relatório de Análise VII
# ## Criando Agrupamentos

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep=';')

# %%
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0   1700.0       500.0  60.0     42.50   Apartamento
# 1   7000.0         0.0   0.0     70.00          Casa
# 2    800.0       390.0  20.0     53.33   Apartamento
# 3    800.0       230.0   0.0     16.67   Apartamento
# 4   1300.0       301.0  17.0     26.00   Apartamento
# 5  22000.0         0.0   0.0     29.33          Casa
# 6   1000.0         0.0   0.0     15.38          Casa
# 7   1500.0       642.0  74.0     21.43   Apartamento
# 8   1500.0       455.0  14.0     16.67   Apartamento
# 9   2000.0       561.0  50.0     50.00   Apartamento

# %% [markdown]
# ### https://pandas.pydata.org/pandas-docs/stable/reference/frame.html

# %%
dados['Valor'].mean().round(2)
# Out:
# 5046.17

# %%
dados['Bairro'].head(30)
# Out:
# 0                   Copacabana
# 1              Jardim Botânico
# 2                       Centro
# 3                 Higienópolis
# 4                     Cachambi
# 5              Barra da Tijuca
# 6                        Ramos
# 7                       Grajaú
# 8          Lins de Vasconcelos
# 9                   Copacabana
# 10                  Copacabana
# 11                  Copacabana
# 12                     Taquara
# 13     Freguesia (Jacarepaguá)
# 14             Barra da Tijuca
# 15                      Tijuca
# 16             Barra da Tijuca
# 17                      Olaria
# 18                      Tijuca
# 19                     Ipanema
# 20                      Tijuca
# 21             Barra da Tijuca
# 22                Campo Grande
# 23                    Botafogo
# 24                  Copacabana
# 25                  Copacabana
# 26    Recreio dos Bandeirantes
# 27                      Leblon
# 28                  Copacabana
# 29             Jardim Oceânico
# Name: Bairro, dtype: object

# %%
# bairros = ['Copacabana', 
#         'Jardim Botânico',
#         'Barra da Tijuca', 
#         'Botafogo',
#         'Leblon',
#         'Flamengo',
#         'Ipanema', 
#         'Tijuca']
# selecao = dados['Bairro'].isin(bairros)
# dados = dados[selecao]

# %%
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor m2 Tipo Agregado
# 0   1700.0       500.0  60.0     42.50   Apartamento
# 1   7000.0         0.0   0.0     70.00          Casa
# 2    800.0       390.0  20.0     53.33   Apartamento
# 3    800.0       230.0   0.0     16.67   Apartamento
# 4   1300.0       301.0  17.0     26.00   Apartamento
# 5  22000.0         0.0   0.0     29.33          Casa
# 6   1000.0         0.0   0.0     15.38          Casa
# 7   1500.0       642.0  74.0     21.43   Apartamento
# 8   1500.0       455.0  14.0     16.67   Apartamento
# 9   2000.0       561.0  50.0     50.00   Apartamento

# %%
dados['Bairro'].drop_duplicates()
# Out:
# 0             Copacabana
# 1        Jardim Botânico
# 2                 Centro
# 3           Higienópolis
# 4               Cachambi
#               ...
# 13855          Bancários
# 15277         Cavalcanti
# 15280       Rio da Prata
# 15412      Cidade Jardim
# 16428        Coelho Neto
# Name: Bairro, Length: 152, dtype: object

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
type(grupo_bairro)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grupo_bairro.groups
# Out:
# {'Abolição': [1553, 3184, 6655, 6951, 7634, 10138, 13165, 14187, 16054, 16639, 17139, 18797, 18805, 20106, 21387], 'Alto da Boa Vista': [2201, 12039, 12556, 13240, 13438, 14518], 'Anchieta': [3017, 8880, 15660, 17811], 'Andaraí': [384, 452, 514, 613, 790, 846, 854, 996, 1191, 1416, 1421, 1685, 1912, 2014, 2683, 3137, 3216, 3489, 3578, 3738, 3856, 4227, 4572, 4773, 4876, 4883, 4961, 5545, 5753, 5990, 6232, 6450, 6529, 6911, 7168, 7408, 7889, 7890, 8064, 8430, 9190, 9290, 9334, 9380, 9713, 9929, 10104, 10255, 10275, 10859, 10940, 10947, 11079, 11516, 11818, 12292, 12762, 13243, 13385, 13389, 13769, 13897, 13931, 13938, 14214, 14592, 14668, 15915, 16009, 16504, 16509, 16599, 16654, 17510, 17769, 17794, 17913, 18212, 18433, 18754, 18888, 18918, 19041, 19668, 19750, 19770, 20100, 20219, 20516, 20866, 21028, 21074, 21114, 21326, 21455, 21543, 21582], 'Anil': [241, 572, 604, 1227, 1632, 1664, 1789, 1932, 2127, 2378, 3586, 3675, 3860, 4153, 4369, 4651, 4769, 4790, 5261, 5340, 5660, 6130, 6150, 6329, 6367, 6483, 6598, 6870, 6923, 7044, 7058, 7430, 7522, 8100, 8153, 8791, 9499, 9631, 9930, 10162, 10321, 10576, 10631, 11953, 11960, 12478, 13189, 13396, 13398, 13415, 14063, 14376, 14528, 14873, 15512, 16581, 16660, 16761, 17527, 17804, 18189, 18323, 18523, 19452, 19556, 19707, 19778, 21131, 21251, 21663, 21717], 'Arpoador': [2775, 3015, 3185, 3350, 4527, 9531, 13867, 14115, 14816, 16538, 18475, 18675], 'Bancários': [13855, 14779, 15906, 20377], 'Bangu': [1292, 1684, 1703, 2133, 3863, 3956, 4080, 7364, 10490, 10528, 10542, 11205, 11424, 11515, 11862, 13479, 14602, 17877, 18182, 20479], 'Barra da Tijuca': [5, 14, 16, 21, 30, 32, 35, 42, 43, 60, 61, 64, 68, 74, 79, 93, 107, 110, 112, 117, 130, 132, 136, 150, 153, 155, 165, 166, 173, 186, 189, 207, 214, 221, 224, 233, 236, 239, 244, 259, 265, 274, 276, 291, 292, 293, 295, 302, 308, 311, 325, 335, 336, 345, 360, 366, 368, 374, 380, 387, 389, 400, 412, 432, 433, 435, 436, 439, 449, 451, 462, 463, 465, 473, 476, 484, 494, 500, 503, 511, 537, 538, 539, 540, 543, 547, 552, 554, 555, 556, 584, 587, 588, 590, 594, 596, 601, 611, 622, 630, ...], 'Barra de Guaratiba': [3676, 10098, 19495, 20876], 'Benfica': [100, 5724, 11274, 18264, 19201], 'Bento Ribeiro': [2250, 2951, 2984, 5173, 6008, 7440, 9878, 10183, 10949, 13094, 13457, 13624, 13761, 14179, 15796, 15837, 18395, 19026, 20159, 20901, 21371, 21633, 21793], 'Bonsucesso': [67, 264, 367, 714, 918, 1288, 1459, 1512, 2064, 2219, 2668, 2678, 3058, 3233, 3258, 4130, 4259, 4353, 4925, 5140, 5451, 5630, 6731, 6866, 7584, 7733, 7977, 8607, 9784, 9888, 10037, 10430, 11447, 11863, 12338, 12356, 12371, 12905, 12923, 14931, 14942, 14959, 15378, 15983, 16148, 16464, 16610, 16889, 16960, 17022, 17420, 17786, 18086, 18890, 18970, 18994, 19652, 20593, 20926], 'Botafogo': [23, 48, 87, 88, 111, 119, 127, 134, 196, 200, 225, 334, 362, 415, 416, 498, 524, 526, 545, 593, 649, 685, 719, 756, 765, 822, 827, 861, 915, 924, 928, 1006, 1043, 1080, 1091, 1110, 1116, 1127, 1140, 1165, 1201, 1205, 1223, 1250, 1282, 1295, 1304, 1317, 1348, 1383, 1414, 1419, 1455, 1517, 1529, 1579, 1630, 1655, 1670, 1699, 1741, 1742, 1788, 1814, 1823, 1826, 1853, 1922, 1931, 1957, 1972, 1981, 1989, 2029, 2066, 2069, 2081, 2083, 2084, 2088, 2097, 2148, 2149, 2165, 2179, 2197, 2242, 2247, 2297, 2352, 2381, 2396, 2413, 2431, 2433, 2470, 2509, 2519, 2532, 2580, ...], 'Braz de Pina': [873, 3995, 4290, 5975, 6812, 6845, 7242, 9121, 9292, 12051, 12242, 12994, 14164, 15111, 15726, 15893, 17658, 18230, 19599, 19655], 'Cachambi': [4, 56, 247, 252, 525, 629, 1389, 1683, 1862, 1949, 2087, 2178, 2556, 2633, 2889, 3009, 3045, 3080, 3755, 4060, 4161, 4195, 4204, 4398, 4446, 4635, 4638, 5272, 5280, 5292, 5308, 5455, 5523, 5572, 5749, 5862, 5919, 5987, 5996, 6173, 6176, 6239, 6378, 6386, 6485, 6600, 6771, 6832, 6850, 7315, 7423, 7441, 7625, 7737, 7907, 8014, 8046, 8066, 8200, 8217, 8600, 8685, 8896, 8904, 8944, 9119, 9123, 9232, 9476, 9578, 9582, 9682, 9855, 10187, 10194, 10353, 10783, 10813, 11075, 11090, 11356, ...

# %%
for bairro, dados in grupo_bairro:
    print('{} -> {}'.format(bairro, dados.Valor.mean().round(2)))
# Out:
# Abolição -> 1195.33
# Alto da Boa Vista -> 3966.67
# Anchieta -> 875.0
# Andaraí -> 1464.71
# Anil -> 2048.87
# Arpoador -> 12923.92
# Bancários -> 1825.0
# Bangu -> 1016.0
# Barra da Tijuca -> 7069.55
# Barra de Guaratiba -> 5550.0
# Benfica -> 996.0
# Bento Ribeiro -> 1030.87
# Bonsucesso -> 1225.93
# Botafogo -> 8791.83
# Braz de Pina -> 1115.0
# Cachambi -> 1157.17
# Cachamorra -> 3000.0
# Cacuia -> 916.67
# Caju -> 850.0
# Camorim -> 1735.23
# Campinho -> 1037.33
# Campo Grande -> 1267.72
# Cascadura -> 948.71
# Catete -> 2267.06
# Catumbi -> 1112.5
# Cavalcanti -> 595.0
# Centro -> 1254.75
# Cidade Jardim -> 12000.0
# Cidade Nova -> 1471.43
# Cocotá -> 1883.33
# Coelho Neto -> 700.0
# Colégio -> 885.0
# Copacabana -> 4126.68
# Cordovil -> 905.56
# Cosme Velho -> 5343.55
# Cosmos -> 658.33
# Curicica -> 1514.57
# Del Castilho -> 1261.3
# Encantado -> 1050.0
# Engenho Novo -> 1035.83
# Engenho da Rainha -> 883.57
# Engenho de Dentro -> 1166.35
# Estácio -> 1233.91
# Flamengo -> 4113.53
# Freguesia (Ilha do Governador) -> 1720.0
# Freguesia (Jacarepaguá) -> 4966.67
# Fátima -> 956.67
# Gamboa -> 1116.67
# Gardênia Azul -> 761.11
# Glória -> 2467.29
# Grajaú -> 2038.62
# Guadalupe -> 700.0
# Guaratiba -> 1232.26
# Gávea -> 6563.69
# Higienópolis -> 1006.25
# Honório Gurgel -> 628.57
# Humaitá -> 3802.31
# Icaraí -> 2393.75
# Ilha do Governador -> 1728.0
# Inhaúma -> 821.43
# Inhoaíba -> 725.0
# Ipanema -> 9352.0
# Irajá -> 1096.01
# Itanhangá -> 9341.27
# Jabour -> 723.33
# Jacarepaguá -> 2046.99
# Jacaré -> 1200.0
# Jardim América -> 714.29
# Jardim Botânico -> 8722.36
# Jardim Carioca -> 2211.11
# Jardim Guanabara -> 2124.69
# Jardim Oceânico -> 7626.09
# Jardim Sulacap -> 1176.67
# Joá -> 16773.48
# Lagoa -> 8147.08
# Lapa -> 1488.78
# Laranjeiras -> 3555.28
# Largo do Machado -> 1880.0
# Leblon -> 8746.34
# Leme -> 3944.76
# Lins de Vasconcelos -> 1086.17
# Madureira -> 1017.66
# Magalhães Bastos -> 640.0
# Maracanã -> 1945.5
# Marechal Hermes -> 844.44
# Maria da Graça -> 1073.33
# Moneró -> 1900.0
# Méier -> 1355.87
# Olaria -> 1016.56
# Oswaldo Cruz -> 823.89
# Paciência -> 580.0
# Padre Miguel -> 786.25
# Paquetá -> 10550.0
# Parada de Lucas -> 1062.5
# Parque Anchieta -> 1287.5
# Pavuna -> 648.95
# Pechincha -> 1357.43
# Pedra de Guaratiba -> 1082.11
# Penha -> 1023.33
# Penha Circular -> 1160.0
# Península -> 7061.54
# Piedade -> 956.54
# Pilares -> 1077.5
# Pitangueiras -> 2725.0
# Portuguesa -> 1272.73
# Praia da Bandeira -> 1300.0
# Praça Seca -> 998.41
# Praça da Bandeira -> 1358.72
# Quintino Bocaiúva -> 924.67
# Ramos -> 958.0
# Realengo -> 908.33
# Recreio dos Bandeirantes -> 3736.61
# Riachuelo -> 1143.9
# Ribeira -> 1420.0
# Rio Comprido -> 1610.24
# Rio da Prata -> 1300.0
# Rocha -> 1086.84
# Rocha Miranda -> 877.0
# Sampaio -> 937.5
# Santa Cruz -> 734.29
# Santa Teresa -> 2713.33
# Santo Cristo -> 1225.0
# Santíssimo -> 756.25
# Saúde -> 950.0
# Senador Camará -> 600.0
# Senador Vasconcelos -> 867.35
# São Conrado -> 8780.89
# São Cristóvão -> 1391.72
# São Francisco Xavier -> 1237.24
# Tanque -> 1335.71
# Taquara -> 1642.14
# Tauá -> 1340.0
# Tijuca -> 2043.52
# Todos os Santos -> 1243.08
# Tomás Coelho -> 737.0
# Turiaçu -> 700.0
# Urca -> 7925.96
# Usina -> 1520.0
# Vargem Grande -> 3358.17
# Vargem Pequena -> 2703.48
# Vaz Lobo -> 845.0
# Vicente de Carvalho -> 1075.71
# Vidigal -> 2600.0
# Vigário Geral -> 970.0
# Vila Isabel -> 1560.83
# Vila Kosmos -> 1311.82
# Vila Militar -> 500.0
# Vila Valqueire -> 1769.58
# Vila da Penha -> 1260.58
# Vista Alegre -> 1114.38
# Zumbi -> 2150.0
# Água Santa -> 861.11

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2)
# Out:
#                      Valor  Condominio
# Bairro
# Abolição           1195.33      191.40
# Alto da Boa Vista  3966.67      885.00
# Anchieta            875.00       19.75
# Andaraí            1464.71      497.71
# Anil               2048.87      455.85
# ...                    ...         ...
# Vila Valqueire     1769.58      276.88
# Vila da Penha      1260.58      232.68
# Vista Alegre       1114.38      210.06
# Zumbi              2150.00     1050.00
# Água Santa          861.11      269.44
#
# [152 rows x 2 columns]

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
sexo = alunos.groupby('Sexo')
sexo = pd.DataFrame(sexo['Notas'].mean().round(2))
sexo.columns = ['Notas Médias']
sexo
# Out:
#       Notas Médias
# Sexo
# F             5.82
# M             7.12

# %%
sexo = alunos.groupby('Sexo')
sexo = pd.DataFrame(sexo['Notas'].mean())
sexo.columns = ['Notas Médias']
sexo
# Out:
#       Notas Médias
# Sexo
# F            5.825
# M            7.125

# %% [markdown]
# # Estatisticas Descritivas

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                    count     mean      std     min     25%     50%     75%  \
# Bairro
# Abolição            15.0  1195.33   425.32   800.0   900.0  1180.0  1200.0
# Alto da Boa Vista    6.0  3966.67  5513.59   600.0  1150.0  1725.0  3275.0
# Anchieta             4.0   875.00   132.29   700.0   812.5   900.0   962.5
# Andaraí             97.0  1464.71   408.11   700.0  1200.0  1400.0  1650.0
# Anil                71.0  2048.87  1523.97   300.0  1100.0  1500.0  2675.0
# ...                  ...      ...      ...     ...     ...     ...     ...
# Vila Valqueire      48.0  1769.58  2203.01   800.0  1000.0  1250.0  1700.0
# Vila da Penha      104.0  1260.58   644.66   450.0   900.0  1100.0  1302.5
# Vista Alegre        16.0  1114.38   199.60   700.0  1012.5  1200.0  1225.0
# Zumbi                2.0  2150.00   777.82  1600.0  1875.0  2150.0  2425.0
# Água Santa           9.0   861.11   174.60   600.0   800.0   850.0   950.0
#
#                        max
# Bairro
# Abolição            2300.0
# Alto da Boa Vista  15000.0
# Anchieta            1000.0
# Andaraí             2950.0
# Anil                7000.0
# ...                    ...
# Vila Valqueire     16000.0
# Vila da Penha       4500.0
# Vista Alegre        1400.0
# Zumbi               2700.0
# Água Santa          1200.0
#
# [152 rows x 8 columns]

# %%
grupo_bairro['Valor'].aggregate(['min', 'max', 'sum']).rename(columns = {'min': 'Mínimo', 'max': 'Máximo', 'sum': 'Soma'})
# Out:
#                    Mínimo   Máximo      Soma
# Bairro
# Abolição            800.0   2300.0   17930.0
# Alto da Boa Vista   600.0  15000.0   23800.0
# Anchieta            700.0   1000.0    3500.0
# Andaraí             700.0   2950.0  142077.0
# Anil                300.0   7000.0  145470.0
# ...                   ...      ...       ...
# Vila Valqueire      800.0  16000.0   84940.0
# Vila da Penha       450.0   4500.0  131100.0
# Vista Alegre        700.0   1400.0   17830.0
# Zumbi              1600.0   2700.0    4300.0
# Água Santa          600.0   1200.0    7750.0
#
# [152 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (20, 10))

# %%
fig = grupo_bairro['Valor'].std().plot.bar(color = 'red')
fig.set_ylabel('Valor do Aluguel')
#fig.set_title('Valor do Aluguel por Bairro', {'fontsize':22})
# Out:
# Text(0, 0.5, 'Valor do Aluguel')

# %%
fig = grupo_bairro['Valor'].mean().plot.bar(color = 'blue')
fig.set_ylabel('Valor do Aluguel')
fig.set_title('Valor Médio do Aluguel por Bairro', {'fontsize':22})
# Out:
# Text(0.5, 1.0, 'Valor Médio do Aluguel por Bairro')

# %%
precos = pd.DataFrame([['Feira', 'Cebola', 2.5], 
                        ['Mercado', 'Cebola', 1.99], 
                        ['Supermercado', 'Cebola', 1.69], 
                        ['Feira', 'Tomate', 4], 
                        ['Mercado', 'Tomate', 3.29], 
                        ['Supermercado', 'Tomate', 2.99], 
                        ['Feira', 'Batata', 4.2], 
                        ['Mercado', 'Batata', 3.99], 
                        ['Supermercado', 'Batata', 3.69]], 
                        columns = ['Local', 'Produto', 'Preço'])
precos
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
produtos = precos.groupby('Produto')
produtos.describe().round(2)
# Out:
#         Preço
#         count  mean   std   min   25%   50%   75%  max
# Produto
# Batata    3.0  3.96  0.26  3.69  3.84  3.99  4.10  4.2
# Cebola    3.0  2.06  0.41  1.69  1.84  1.99  2.24  2.5
# Tomate    3.0  3.43  0.52  2.99  3.14  3.29  3.64  4.0

# %%
estatisticas = ['mean', 'std', 'min', 'max']
nomes = {'mean': 'Média', 'std': 'Desvio Padrão', 
    'min': 'Mínimo', 'max': 'Máximo'}
produtos['Preço'].aggregate(estatisticas).rename(columns = nomes).round(2)
# Out:
#          Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Batata    3.96           0.26    3.69     4.2
# Cebola    2.06           0.41    1.69     2.5
# Tomate    3.43           0.52    2.99     4.0

# %%
# 1 e 2
# 3 e 4
# 5 e 6
# 7 e 8
classes = [0, 2, 4, 6, 100]

# %%
quartos = pd.cut(dados.Quartos, classes)

# %%
quartos
# Out:
# 199      (0, 2]
# 456      (0, 2]
# 5751     (0, 2]
# 9479     (2, 4]
# 13490    (0, 2]
# 13781    (0, 2]
# 14193    (0, 2]
# 16664    (0, 2]
# 16983    (0, 2]
# Name: Quartos, dtype: category
# Categories (4, interval[int64, right]): [(0, 2] < (2, 4] < (4, 6] < (6, 100]]

# %%
pd.value_counts(quartos)
# Out:
# (0, 2]      8
# (2, 4]      1
# (4, 6]      0
# (6, 100]    0
# Name: Quartos, dtype: int64

# %%
labels = ['1 e 2 quartos', '3 e 4 quartos', '5 e 6 quartos', '7 quartos ou mais' ]

# %%
quartos = pd.cut(dados.Quartos, classes, labels = labels)

# %%
pd.value_counts(quartos)
# Out:
# 1 e 2 quartos        8
# 3 e 4 quartos        1
# 5 e 6 quartos        0
# 7 quartos ou mais    0
# Name: Quartos, dtype: int64

# %%
quartos = pd.cut(dados.Quartos, classes, labels = labels, include_lowest = True)
